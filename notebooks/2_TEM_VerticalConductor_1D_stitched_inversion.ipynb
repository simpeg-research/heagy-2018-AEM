# %% [markdown]
# ## Perform a 1D inversion
#
# This notebook reproduces the 1D inversion (Figure 5) shown in
#
# Heagy, L., Kang, S., Cockett, R., and Oldenburg, D., 2018, _Open source software for simulations and inversions of airborne electromagnetic data_, AEM 2018 International Workshop on Airborne Electromagnetics

# %%
import numpy as np
from scipy.constants import mu_0
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm

from pymatsolver import Pardiso
from SimPEG import (EM, Mesh, Maps, SolverLU, DataMisfit, Regularization,
                    Optimization, InvProblem, Inversion, Directives, Utils)

# %matplotlib inline

# %%
matplotlib.rcParams['font.size'] = 16

# %%
dobs = np.load("dobs.npy")
x = np.load('x.npy')
times = np.logspace(np.log10(5e-5), np.log10(2.5e-3), 21)
nSrc = x.size
DOBS = dobs.reshape((nSrc, 2, times.size))

# %% [markdown]
# ## Define the forward simulation mesh

# %%
def get_1d_cyl_mesh():
    cs, ncx, ncz, npad = 50., 10, 10, 10
    pad_rate = 1.3
    hx = [(cs, ncx),  (cs, npad, pad_rate)]
    hz = [(cs, npad, -pad_rate), (cs, ncz), (cs, npad, pad_rate)]
    mesh = Mesh.CylMesh([hx, 1, hz], '00C')
    return mesh

# %%
def run_1d_tem_inversion(args):
    sig0, dobs, std, eps, rxloc, srcloc, times = args
    mesh = get_1d_cyl_mesh()
    active = mesh.vectorCCz < 0.
    actMap = Maps.InjectActiveCells(mesh, active, np.log(1e-8), nC=mesh.nCz)
    mapping = Maps.ExpMap(mesh) * Maps.SurjectVertical1D(mesh) * actMap
    rx = EM.TDEM.Rx.Point_dbdt(
        rxloc,
        times,
        'z'
    )
    src = EM.TDEM.Src.CircularLoop([rx], orientation='z', loc=srcloc)
    survey = EM.TDEM.Survey([src])
    prb = EM.TDEM.Problem3D_b(mesh, sigmaMap=mapping)

    prb.Solver = Pardiso
    prb.timeSteps = [(1e-05, 15), (5e-5, 10), (2e-4, 10)]
    prb.pair(survey)
    survey.dobs = dobs
    survey.std = std
    survey.eps = eps

    dmisfit = DataMisfit.l2_DataMisfit(survey)
    regMesh = Mesh.TensorMesh([mesh.hz[mapping.maps[-1].indActive]])
    reg = Regularization.Tikhonov(
        regMesh, alpha_s=1./mesh.hx.min()**2, alpha_x=1.
    )
    opt = Optimization.InexactGaussNewton(maxIter=10, LSshorten=0.5)
    invProb = InvProblem.BaseInvProblem(dmisfit, reg, opt, beta=20)
    # Create an inversion object
#     beta = Directives.BetaSchedule(coolingFactor=2, coolingRate=2)
#     betaest = Directives.BetaEstimate_ByEig(beta0_ratio=1e0)
    target=Directives.TargetMisfit()
    inv = Inversion.BaseInversion(invProb, directiveList=[target])
    m0 = np.log(np.ones(actMap.nP)*sig0)
    prb.counter = opt.counter = Utils.Counter()
    mopt = inv.run(m0)
    return mopt, invProb.dpred

# %% [markdown]
# ## Run the 1D inversions

# %%
from multiprocessing import Pool

# %%
p = Pool()
# Out:
# SimPEG.InvProblem will set Regularization.mref to m0.
# SimPEG.InvProblem will set Regularization.mref to m0.
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***model has any nan: 0
#
# model has any nan: 0
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# model has any nan: 0
# x0 has any nan: 0
# -----------------------------------------------------------------------------
# x0 has any nan: 0
# ============================ Inexact Gauss Newton ============================
# x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  1.87e+03  0.00e+00  1.87e+03    7.78e+02      0
#    0  2.00e+01  1.04e+03  0.00e+00  1.04e+03    7.17e+02      0
#    0  2.00e+01  2.84e+03  0.00e+00  2.84e+03    6.16e+02      0
#    0  2.00e+01  6.58e+03  0.00e+00  6.58e+03    5.51e+03      0
#    1  2.00e+01  2.41e+03  1.74e-01  2.41e+03    2.36e+03      0
#    1  2.00e+01  2.39e+02  2.08e-01  2.43e+02    6.76e+02      1
#    1  2.00e+01  4.29e+02  3.36e-02  4.30e+02    2.80e+02      1
#    1  2.00e+01  3.71e+02  2.78e-01  3.77e+02    5.64e+02      2
#    2  2.00e+01  1.27e+02  1.65e-01  1.30e+02    5.51e+01      0
#    2  2.00e+01  1.92e+02  2.83e-01  1.98e+02    8.72e+02      0   Skip BFGS
#    2  2.00e+01  2.16e+03  4.92e-01  2.17e+03    3.24e+03      1   Skip BFGS
#    2  2.00e+01  3.09e+02  8.94e-02  3.11e+02    8.90e+01      2
#    3  2.00e+01  7.09e+01  2.57e-01  7.60e+01    7.49e+01      0
#    3  2.00e+01  1.44e+03  4.90e-01  1.45e+03    4.41e+02      0
#    3  2.00e+01  1.01e+02  1.58e-01  1.04e+02    1.08e+02      2
#    3  2.00e+01  3.02e+02  1.72e-01  3.06e+02    2.37e+02      0   Skip BFGS
#    4  2.00e+01  5.94e+01  2.86e-01  6.51e+01    2.14e+02      1   Skip BFGS
#    4  2.00e+01  1.31e+03  7.12e-01  1.32e+03    7.91e+02      3   Skip BFGS
#    4  2.00e+01  9.78e+01  1.74e-01  1.01e+02    1.95e+02      2   Skip BFGS
#    4  2.00e+01  2.96e+02  1.96e-01  3.00e+02    3.38e+02      3
#    5  2.00e+01  5.10e+01  2.89e-01  5.68e+01    2.29e+02      1
#    5  2.00e+01  1.12e+03  1.28e+00  1.15e+03    7.87e+02      2   Skip BFGS
#    5  2.00e+01  9.61e+01  1.71e-01  9.96e+01    2.01e+02      3
#    6  2.00e+01  4.76e+01  2.72e-01  5.30e+01    2.28e+02      0   Skip BFGS
#    5  2.00e+01  2.93e+02  2.54e-01  2.98e+02    2.43e+02      0
#    6  2.00e+01  9.69e+02  2.71e+00  1.02e+03    9.35e+02      1   Skip BFGS
#    6  2.00e+01  9.43e+01  1.67e-01  9.77e+01    1.23e+02      0   Skip BFGS
#    7  2.00e+01  8.76e+02  2.72e+00  9.30e+02    7.30e+01      0
#    7  2.00e+01  4.55e+01  2.90e-01  5.13e+01    2.09e+02      2
#    6  2.00e+01  2.86e+02  2.72e-01  2.92e+02    2.74e+02      3
#    7  2.00e+01  9.26e+01  1.67e-01  9.60e+01    1.24e+02      1
#    8  2.00e+01  8.30e+02  3.34e+00  8.97e+02    1.77e+02      3
#    8  2.00e+01  4.10e+01  2.86e-01  4.68e+01    9.80e+01      0   Skip BFGS
#    7  2.00e+01  2.85e+02  2.48e-01  2.90e+02    2.82e+02      4   Skip BFGS
#    8  2.00e+01  9.23e+01  1.75e-01  9.58e+01    1.31e+02      3
#    9  2.00e+01  4.07e+01  2.95e-01  4.66e+01    1.04e+02      1
#    9  2.00e+01  7.89e+02  3.92e+00  8.68e+02    4.36e+02      3
#    8  2.00e+01  2.83e+02  2.55e-01  2.89e+02    2.67e+02      2   Skip BFGS
#    9  2.00e+01  9.21e+01  1.73e-01  9.56e+01    1.32e+02      3
#   10  2.00e+01  4.07e+01  2.91e-01  4.65e+01    8.58e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.0314e-02 <= tolF*(1+|f0|) = 2.8400e+02
# 1 : |xc-x_last| = 3.2420e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 8.5758e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.5758e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#   10  2.00e+01  6.98e+02  6.40e+00  8.25e+02    5.14e+02      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.2141e+01 <= tolF*(1+|f0|) = 6.5822e+02
# 1 : |xc-x_last| = 1.9078e+00 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 5.1433e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1433e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  3.21e+03  0.00e+00  3.21e+03    4.71e+02      0
#    0  2.00e+01  8.64e+02  0.00e+00  8.64e+02    4.85e+02      0
#    9  2.00e+01  2.82e+02  2.79e-01  2.88e+02    2.38e+02      1
#    1  2.00e+01  1.80e+03  1.40e-01  1.80e+03    8.25e+02      3
#   10  2.00e+01  9.20e+01  1.73e-01  9.54e+01    1.27e+02      3
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.9567e-01 <= tolF*(1+|f0|) = 1.8706e+02
# 1 : |xc-x_last| = 9.6501e-02 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.2694e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2694e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  2.37e+03  0.00e+00  2.37e+03    7.27e+02      0
#   10  2.00e+01  2.81e+02  2.38e-01  2.86e+02    2.07e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.5012e+00 <= tolF*(1+|f0|) = 1.0371e+02
# 1 : |xc-x_last| = 4.5179e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 2.0707e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.0707e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    1  2.00e+01  6.15e+02  1.38e-01  6.18e+02    3.49e+02      2
#    0  2.00e+01  1.43e+03  0.00e+00  1.43e+03    7.73e+02      0
#    2  2.00e+01  4.05e+02  2.46e-01  4.10e+02    7.72e+02      1
#    1  2.00e+01  7.44e+02  1.18e-01  7.46e+02    8.47e+02      2
#    1  2.00e+01  2.75e+02  9.42e-02  2.77e+02    1.06e+02      1
#    2  2.00e+01  5.57e+02  3.52e-01  5.64e+02    7.82e+02      2
#    2  2.00e+01  4.79e+02  2.82e-01  4.84e+02    1.46e+03      0
#    3  2.00e+01  2.90e+02  2.47e-01  2.95e+02    8.11e+02      2
#    2  2.00e+01  2.27e+02  1.01e-01  2.29e+02    1.32e+02      2
#    3  2.00e+01  4.56e+02  4.36e-01  4.64e+02    6.91e+02      1
#    3  2.00e+01  1.04e+02  2.28e-01  1.09e+02    1.85e+02      0
#    4  2.00e+01  2.15e+02  2.85e-01  2.21e+02    8.12e+02      2   Skip BFGS
#    4  2.00e+01  4.10e+02  1.15e+00  4.33e+02    7.43e+02      2
#    4  2.00e+01  9.19e+01  2.19e-01  9.63e+01    2.23e+02      2
#    3  2.00e+01  2.22e+02  1.07e-01  2.24e+02    1.61e+02      3   Skip BFGS
#    5  2.00e+01  1.55e+02  4.96e-01  1.65e+02    9.83e+02      1   Skip BFGS
#    6  2.00e+01  8.97e+01  4.90e-01  9.95e+01    6.57e+01      0
#    5  2.00e+01  3.88e+02  1.98e+00  4.27e+02    7.00e+02      1   Skip BFGS
#    5  2.00e+01  8.54e+01  2.62e-01  9.06e+01    2.44e+02      2   Skip BFGS
#    4  2.00e+01  2.19e+02  1.13e-01  2.21e+02    1.50e+02      2
#    7  2.00e+01  8.52e+01  6.85e-01  9.89e+01    1.68e+02      1   Skip BFGS
#    6  2.00e+01  3.61e+02  1.98e+00  4.01e+02    5.82e+02      2
#    6  2.00e+01  8.42e+01  2.66e-01  8.95e+01    2.43e+02      3
#    5  2.00e+01  2.18e+02  1.17e-01  2.20e+02    1.71e+02      3
#    8  2.00e+01  8.43e+01  6.31e-01  9.69e+01    2.59e+02      2
#    7  2.00e+01  3.50e+02  1.12e+00  3.73e+02    3.72e+02      1   Skip BFGS
#    7  2.00e+01  7.67e+01  4.08e-01  8.49e+01    2.10e+02      1
#    6  2.00e+01  2.17e+02  1.39e-01  2.20e+02    1.88e+02      3
#    9  2.00e+01  8.29e+01  6.36e-01  9.56e+01    2.50e+02      3
#    8  2.00e+01  3.37e+02  1.45e+00  3.66e+02    3.37e+02      2
#    8  2.00e+01  7.39e+01  4.32e-01  8.25e+01    1.90e+02      2
#    7  2.00e+01  2.16e+02  1.28e-01  2.19e+02    1.48e+02      1
#   10  2.00e+01  7.38e+01  8.40e-01  9.06e+01    2.35e+02      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 5.0216e+00 <= tolF*(1+|f0|) = 3.2073e+02
# 1 : |xc-x_last| = 1.1347e+00 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 2.3519e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3519e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    9  2.00e+01  3.09e+02  2.38e+00  3.57e+02    4.01e+02      1
#    0  2.00e+01  3.23e+03  0.00e+00  3.23e+03    3.20e+02      0
#    9  2.00e+01  7.34e+01  3.93e-01  8.12e+01    1.32e+02      0
#    8  2.00e+01  2.16e+02  1.37e-01  2.18e+02    1.64e+02      1
#   10  2.00e+01  3.07e+02  1.84e+00  3.44e+02    3.26e+02      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2639e+01 <= tolF*(1+|f0|) = 8.6478e+01
# 1 : |xc-x_last| = 1.2733e+00 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 3.2562e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.2562e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  3.20e+03  0.00e+00  3.20e+03    4.75e+02      0
#    1  2.00e+01  3.09e+03  2.99e-01  3.09e+03    3.49e+03      3
#   10  2.00e+01  7.05e+01  4.08e-01  7.87e+01    1.21e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.5726e+00 <= tolF*(1+|f0|) = 2.3747e+02
# 1 : |xc-x_last| = 4.9046e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.2091e+02 <= tolG          = 1.0000e-01
#    9  2.00e+01  2.15e+02  1.52e-01  2.18e+02    1.23e+02      0
# 0 : |proj(x-g)-x|    = 1.2091e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  2.36e+03  0.00e+00  2.36e+03    7.21e+02      0
#    1  2.00e+01  1.79e+03  1.41e-01  1.79e+03    8.23e+02      3
#    2  2.00e+01  2.83e+03  3.02e-01  2.83e+03    4.06e+03      3
#    1  2.00e+01  8.13e+02  1.11e-01  8.16e+02    8.34e+02      2
#   10  2.00e+01  2.14e+02  1.70e-01  2.18e+02    1.49e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.2271e-01 <= tolF*(1+|f0|) = 1.4276e+02
# 1 : |xc-x_last| = 2.2174e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.4935e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4935e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  1.43e+03  0.00e+00  1.43e+03    7.82e+02      0
#    2  2.00e+01  3.81e+02  2.49e-01  3.86e+02    7.08e+02      1
#    2  2.00e+01  6.86e+02  2.92e-01  6.91e+02    1.82e+03      0
#    1  2.00e+01  1.56e+02  1.04e-01  1.58e+02    7.50e+01      1
#    3  2.00e+01  2.81e+03  3.12e-01  2.82e+03    4.05e+03      7
#    3  2.00e+01  1.61e+02  2.32e-01  1.66e+02    2.26e+02      0
#    3  2.00e+01  2.74e+02  2.49e-01  2.79e+02    7.71e+02      2
#    2  2.00e+01  1.52e+02  1.45e-01  1.54e+02    4.88e+02      1
#    4  2.00e+01  2.79e+03  3.58e-01  2.80e+03    3.94e+03      5   Skip BFGS
#    4  2.00e+01  2.03e+02  2.85e-01  2.09e+02    8.01e+02      2   Skip BFGS
#    4  2.00e+01  1.48e+02  2.32e-01  1.53e+02    3.36e+02      2
#    3  2.00e+01  1.14e+02  1.11e-01  1.16e+02    1.25e+02      0
#    5  2.00e+01  1.46e+02  4.90e-01  1.56e+02    9.84e+02      1   Skip BFGS
#    5  2.00e+01  2.78e+03  3.51e-01  2.79e+03    3.99e+03      7
#    6  2.00e+01  7.95e+01  4.85e-01  8.92e+01    6.63e+01      0
#    5  2.00e+01  1.42e+02  2.52e-01  1.47e+02    3.36e+02      3   Skip BFGS
#    4  2.00e+01  1.12e+02  1.15e-01  1.14e+02    1.39e+02      1
#    7  2.00e+01  7.53e+01  5.30e-01  8.59e+01    9.21e+01      2   Skip BFGS
#    6  2.00e+01  1.34e+02  3.38e-01  1.41e+02    3.07e+02      2
#    6  2.00e+01  2.75e+03  3.50e-01  2.75e+03    3.85e+03      5   Skip BFGS
#    5  2.00e+01  1.11e+02  1.30e-01  1.13e+02    1.49e+02      3   Skip BFGS
#    8  2.00e+01  7.33e+01  5.44e-01  8.42e+01    1.07e+02      3
#    7  2.00e+01  1.31e+02  3.35e-01  1.38e+02    3.05e+02      3
#    7  2.00e+01  2.74e+03  3.50e-01  2.75e+03    3.82e+03      7
#    6  2.00e+01  1.11e+02  1.34e-01  1.13e+02    1.51e+02      3
#    9  2.00e+01  7.18e+01  5.81e-01  8.34e+01    8.89e+01      2
#    8  2.00e+01  1.25e+02  4.04e-01  1.33e+02    1.66e+02      0
#    7  2.00e+01  1.10e+02  1.38e-01  1.13e+02    1.58e+02      4
#    8  2.00e+01  2.73e+03  3.48e-01  2.74e+03    3.83e+03      6
#   10  2.00e+01  7.00e+01  6.44e-01  8.29e+01    1.04e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.6364e-01 <= tolF*(1+|f0|) = 3.2019e+02
# 1 : |xc-x_last| = 5.7625e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.0449e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0449e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    9  2.00e+01  1.19e+02  5.33e-01  1.29e+02    1.71e+02      2
#    0  2.00e+01  2.83e+03  0.00e+00  2.83e+03    6.22e+02      0
#    8  2.00e+01  1.10e+02  1.49e-01  1.13e+02    1.57e+02      3
#    9  2.00e+01  2.72e+03  3.50e-01  2.73e+03    3.75e+03      6
#    1  2.00e+01  4.22e+02  2.62e-01  4.28e+02    6.41e+02      2
#   10  2.00e+01  1.15e+02  4.64e-01  1.24e+02    7.47e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 5.3439e+00 <= tolF*(1+|f0|) = 2.3629e+02
# 1 : |xc-x_last| = 1.1690e+00 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 7.4716e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.4716e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  1.88e+03  0.00e+00  1.88e+03    8.01e+02      0
#    9  2.00e+01  1.10e+02  1.50e-01  1.13e+02    1.48e+02      2
#    2  2.00e+01  2.06e+02  2.83e-01  2.11e+02    8.73e+02      0
#    1  2.00e+01  2.76e+02  2.10e-01  2.80e+02    7.72e+02      1
#   10  2.00e+01  2.72e+03  3.54e-01  2.72e+03    3.74e+03      7
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.0289e+00 <= tolF*(1+|f0|) = 3.2309e+02
# 1 : |xc-x_last| = 1.1303e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 3.7446e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.7446e+03 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  3.21e+03  0.00e+00  3.21e+03    3.05e+02      0
#    3  2.00e+01  7.93e+01  2.53e-01  8.44e+01    6.90e+01      0
#    2  2.00e+01  1.31e+02  1.61e-01  1.34e+02    5.54e+01      0
#   10  2.00e+01  1.09e+02  1.57e-01  1.12e+02    1.40e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.8098e-01 <= tolF*(1+|f0|) = 1.4273e+02
# 1 : |xc-x_last| = 2.5755e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.4022e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4022e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  1.00e+03  0.00e+00  1.00e+03    6.74e+02      0
#    4  2.00e+01  7.09e+01  2.27e-01  7.55e+01    2.40e+02      1   Skip BFGS
#    1  2.00e+01  2.65e+03  7.73e-02  2.65e+03    5.26e+02      4
#    1  2.00e+01  3.81e+02  3.48e-02  3.82e+02    2.47e+02      1
#    3  2.00e+01  1.05e+02  1.57e-01  1.08e+02    1.18e+02      2
#    5  2.00e+01  6.94e+01  2.23e-01  7.39e+01    3.43e+02      0
#    2  2.00e+01  2.44e+03  4.09e-01  2.45e+03    2.86e+03      3
#    4  2.00e+01  9.88e+01  1.53e-01  1.02e+02    1.62e+02      2   Skip BFGS
#    2  2.00e+01  2.70e+02  8.26e-02  2.72e+02    9.93e+01      2
#    6  2.00e+01  5.38e+01  2.12e-01  5.80e+01    2.80e+01      0
#    3  2.00e+01  2.44e+03  3.40e-01  2.45e+03    4.20e+03      3
#    5  2.00e+01  9.77e+01  1.57e-01  1.01e+02    1.62e+02      3   Skip BFGS
#    3  2.00e+01  2.57e+02  1.51e-01  2.60e+02    1.41e+02      3   Skip BFGS
#    7  2.00e+01  5.28e+01  2.20e-01  5.72e+01    3.85e+01      0
#    4  2.00e+01  2.24e+03  3.80e-01  2.25e+03    5.35e+03      2   Skip BFGS
#    6  2.00e+01  9.68e+01  1.78e-01  1.00e+02    1.66e+02      2
#    8  2.00e+01  5.19e+01  2.24e-01  5.64e+01    7.27e+01      0
#    5  2.00e+01  1.57e+03  5.46e-01  1.58e+03    4.08e+03      1   Skip BFGS
#    4  2.00e+01  2.52e+02  1.55e-01  2.55e+02    1.98e+02      3
#    6  2.00e+01  9.71e+02  9.02e-01  9.89e+02    6.17e+02      0   Skip BFGS
#    9  2.00e+01  5.09e+01  2.26e-01  5.55e+01    2.08e+01      0
#    7  2.00e+01  9.59e+01  1.74e-01  9.94e+01    1.55e+02      2
#    5  2.00e+01  2.49e+02  1.72e-01  2.53e+02    2.14e+02      4
#    7  2.00e+01  9.03e+02  1.11e+00  9.26e+02    8.70e+02      4
#   10  2.00e+01  5.02e+01  2.43e-01  5.51e+01    3.68e+01      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.0479e-01 <= tolF*(1+|f0|) = 2.8295e+02
# 1 : |xc-x_last| = 3.5702e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 3.6811e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.6811e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    8  2.00e+01  9.49e+01  1.96e-01  9.89e+01    1.34e+02      1
#    0  2.00e+01  9.94e+02  0.00e+00  9.94e+02    4.62e+02      0
#    6  2.00e+01  2.44e+02  1.80e-01  2.48e+02    1.88e+02      1
#    8  2.00e+01  8.79e+02  1.28e+00  9.04e+02    9.10e+02      3
#    9  2.00e+01  9.53e+01  1.76e-01  9.88e+01    1.32e+02      2
#    1  2.00e+01  8.12e+02  1.67e-01  8.15e+02    7.02e+02      2
#    7  2.00e+01  2.42e+02  2.08e-01  2.47e+02    2.21e+02      3
#   10  2.00e+01  9.50e+01  1.87e-01  9.87e+01    1.28e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.1329e-01 <= tolF*(1+|f0|) = 1.8859e+02
# 1 : |xc-x_last| = 1.4394e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.2828e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2828e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    9  2.00e+01  8.57e+02  1.54e+00  8.88e+02    1.18e+03      4
#    8  2.00e+01  2.37e+02  3.99e-01  2.45e+02    2.46e+02      1   Skip BFGS
#    2  2.00e+01  7.25e+02  2.67e-01  7.30e+02    7.83e+02      3
#   10  2.00e+01  8.54e+02  1.52e+00  8.85e+02    1.26e+03      5
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.4905e+00 <= tolF*(1+|f0|) = 3.2117e+02
# 1 : |xc-x_last| = 4.5112e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.2582e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2582e+03 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    9  2.00e+01  2.38e+02  3.30e-01  2.44e+02    2.28e+02      2
#    3  2.00e+01  6.43e+02  9.12e-01  6.61e+02    1.12e+03      2   Skip BFGS
#    4  2.00e+01  5.48e+02  8.51e-01  5.65e+02    8.67e+02      1
#   10  2.00e+01  2.37e+02  3.71e-01  2.44e+02    2.38e+02      3
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.8687e-01 <= tolF*(1+|f0|) = 1.0011e+02
# 1 : |xc-x_last| = 2.4558e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 2.3783e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3783e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    5  2.00e+01  5.34e+02  1.09e+00  5.56e+02    9.26e+02      3   Skip BFGS
#    6  2.00e+01  5.22e+02  1.45e+00  5.51e+02    9.70e+02      3
#    7  2.00e+01  4.27e+02  1.92e+00  4.65e+02    4.04e+02      0   Skip BFGS
#    8  2.00e+01  4.12e+02  2.05e+00  4.53e+02    4.43e+02      3
#    9  2.00e+01  4.08e+02  2.07e+00  4.49e+02    4.50e+02      5   Skip BFGS
#   10  2.00e+01  3.96e+02  2.00e+00  4.36e+02    3.23e+02      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3757e+01 <= tolF*(1+|f0|) = 9.9464e+01
# 1 : |xc-x_last| = 8.4051e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 3.2325e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.2325e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#     SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#     ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  2.00e+01  4.35e+03  0.00e+00  4.35e+03    3.52e+03      0
#    1  2.00e+01  2.90e+03  1.66e-01  2.90e+03    3.32e+03      1
#    2  2.00e+01  1.47e+03  2.62e-01  1.48e+03    9.59e+02      0
#    3  2.00e+01  1.32e+03  4.41e-01  1.33e+03    1.23e+03      2   Skip BFGS
#    4  2.00e+01  1.23e+03  6.87e-01  1.24e+03    1.38e+03      2   Skip BFGS
#    5  2.00e+01  1.14e+03  1.01e+00  1.16e+03    1.43e+03      2   Skip BFGS
#    6  2.00e+01  9.79e+02  1.04e+00  1.00e+03    1.04e+02      0   Skip BFGS
#    7  2.00e+01  9.25e+02  1.53e+00  9.56e+02    5.00e+02      2   Skip BFGS
#    8  2.00e+01  9.04e+02  1.83e+00  9.40e+02    6.26e+02      2   Skip BFGS
#    9  2.00e+01  8.73e+02  1.82e+00  9.09e+02    4.94e+01      0   Skip BFGS
#   10  2.00e+01  8.49e+02  2.19e+00  8.93e+02    1.94e+02      2   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.6944e+01 <= tolF*(1+|f0|) = 4.3471e+02
# 1 : |xc-x_last| = 6.8639e-01 <= tolX*(1+|x0|) = 2.7754e+00
# 0 : |proj(x-g)-x|    = 1.9445e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9445e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------

# %%
sig0 = 1e-3
std = 0.05
eps = 0.
rxloc = np.array([[0., 0., 30.]])
srcloc = np.array([[0., 0., 30.]])
results = p.map(run_1d_tem_inversion, [(sig0, DOBS[iSrc, 0, :], std, eps, rxloc, srcloc, times) for iSrc in range(len(x))])

# %% [markdown]
# ## Predicted data and resultant model

# %%
DPRED = [results[i][1] for i in range (nSrc)]
MOPT = [results[i][0] for i in range (nSrc)]

# %%
pred = np.vstack(DPRED)
sigma = Utils.mkvc(np.exp(np.vstack(MOPT)))

# %%
dobs = DOBS[:, 0, :].flatten()
dpred = pred.flatten()
W = Utils.sdiag(1./(dobs*std + eps))
misfit = W*(dobs-dpred)
misfit = misfit.dot(misfit)

print('global misfit {:1.0f}, target misfit {:1.0f}'.format(misfit, len(dobs)))
print('chifact: {:1.1f}'.format(misfit/len(dobs)))
# Out:
# global misfit 14534, target misfit 378
# chifact: 38.4

# %%
# fig = plt.figure(figsize=(5, 3))
fig = plt.figure(figsize=(9, 4))
for i in range(times.size):
    plt.plot(x, -DOBS[:, 0, i].flatten(), 'k-', lw=1, label='obs' if i == 0 else None)
    plt.plot(x, -pred[:,i].flatten(), 'bx', markeredgewidth=1.5, label='pred' if i == 0 else None)    
plt.yscale('log')   
plt.grid(which="both")
plt.legend(bbox_to_anchor=[1, 1])
plt.xlabel('x')
plt.ylabel('Voltage (V/Am$^2$)')
# plt.ylim(1e-15, 1e-9)
# Out:
# Text(0,0.5,'Voltage (V/Am$^2$)')

# %%
mesh1d = get_1d_cyl_mesh()
hx = np.ones(nSrc) * 50
mesh2D = Mesh.TensorMesh([hx, mesh1d.hz[mesh1d.vectorCCz<0.]], x0="CN")

# %%
def rect2D(p1, p2):    
    xy = np.c_[np.r_[p1[0], p2[0], p2[0], p1[0], p1[0]], np.r_[p1[1], p1[1], p2[1], p2[1], p1[1]]]
    return xy

p1 = np.r_[-50, -450]
p2 = np.r_[50, -50]
xy_box = rect2D(p1, p2)

# %%
from matplotlib.colors import LogNorm

fig, ax = plt.subplots(2, 1, figsize=(8, 3.5*2))

out = mesh2D.plotImage(sigma, pcolorOpts={'norm':LogNorm()}, clim=[1e-3, 1e-1], ax=ax[0])
cb = plt.colorbar(out[0], fraction=0.025, extend="min", ax=ax[0])
ax[0].set_ylim(-500, 0.)
plt.gca().set_aspect(1)
cb.set_label('Conductivity (S/m)')
ax[0].set_title("(a)")

ax[0].plot(xy_box[:,0], xy_box[:,1], 'w--')

for i in range(times.size):
    ax[1].plot(x, -DOBS[:, 0, i].flatten(), 'k-', lw=1, label='obs' if i == 0 else None)
    ax[1].plot(x, -pred[:,i].flatten(), 'bx', markeredgewidth=1.5, label='pred' if i == 0 else None)    
ax[1].set_yscale('log')   
ax[1].grid(which="both")
ax[1].legend(bbox_to_anchor=[1, 1])
ax[1].set_xlabel('x')
ax[1].set_ylabel('Voltage (V/Am$^2$)')
ax[1].set_title("(b)")

plt.tight_layout()

fig.savefig('../figures/1Dinversion.png', dpi=350, bbox_inches="tight")
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1398: UserWarning: aspect is not supported for Axes with xscale=linear, yscale=log
#   'yscale=%s' % (xscale, yscale))

# %%
np.save('1Dinversion/dpred_1d_stitched', pred)
np.save('1Dinversion/sigma_1d_stitched', sigma)
mesh2D.save(filename="1Dinversion/mesh_1d_stitched.json")
# Out:
# '/Users/lindseyjh/git/simpeg-research/heagy-2018-aem/notebooks/1Dinversion/mesh_1d_stitched.json'
